# %%
import crime as cr

cr.help()
# Out:
# Docs: https://pypi.org/project/crime/
#
# DataFrame with info on all datasets:
# >>> cr.sources()
#
# Details on a dataset, and description of all columns
# >>> cr.sources('dataset_name')
#
# Quickly preview its first 5 rows
# >>> cr.load('dataset_name')
#
# Load full dataset
# >>> cr.load('dataset_name', full=True)
#
# Add a new source
# >>> cr.add_source("some_nickname", "some_id", "base_url")
#
# Revert to using the default sources
# >>> cr.reset_sources()

# %%
cr.columns('crime_97_15')
# Out:
#                                         Name           Type     Null  \
# agency_name                      Agency Name           text      380
# agency_type_name            Agency Type Name           text      380
# city_name                          City Name           text   939702
# primary_county                Primary County           text    24938
# incident_hour                  Incident Hour         number   139976
# offense_name                    Offense Name           text     2376
# crime_against                  Crime Against           text     2376
# offense_category_name  Offense Category Name           text     2585
# age_num                              Age Num         number  2337245
# incident_date                  Incident Date  calendar_date     2756
#
#                        Non_Null   Avg   Max  Min   Sum
# agency_name             4951902  None   NaN  NaN  None
# agency_type_name        4951902  None   NaN  NaN  None
# ...
